# %%
    # Thư viện cơ bản
import pandas as pd
import numpy as np

# Vẽ biểu đồ thô ban đầu
import matplotlib.pyplot as plt
import seaborn as sns

# Thư viện kiểm tra thống kê
from scipy import stats

# %%
# Đọc dữ liệu
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# Xem tổng quan
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Kiểm tra tổng số missing value từng cột
missing_values = df.isnull().sum()

# Chỉ in ra các cột nào có missing > 0
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
# Kiểm tra tổng số dòng trùng lặp
duplicate_count = df.duplicated().sum()

print(f"Số dòng bị trùng lặp: {duplicate_count}")
# Out:
# Số dòng bị trùng lặp: 0

# %%
# Target variable
target_col = 'Attrition'

# Numerical variables
numerical_cols = [
    'Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 
    'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 
    'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 
    'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 
    'YearsWithCurrManager'
]

# Categorical variables
categorical_cols = [
    'BusinessTravel', 'Department', 'EducationField', 
    'Gender', 'JobRole', 'MaritalStatus', 'OverTime'
]

# Ordinal variables
ordinal_cols = [
    'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 
    'JobLevel', 'JobSatisfaction', 'PerformanceRating', 
    'RelationshipSatisfaction', 'StockOptionLevel', 'WorkLifeBalance'
]

# Columns to drop
drop_cols = ['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber']

# %%
# Thống kê mô tả nhóm biến số
df[numerical_cols].describe().T
# Out:
#                           count          mean          std     min     25%  \
# Age                      1470.0     36.923810     9.135373    18.0    30.0
# DailyRate                1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome         1470.0      9.192517     8.106864     1.0     2.0
# HourlyRate               1470.0     65.891156    20.329428    30.0    48.0
# MonthlyIncome            1470.0   6502.931293  4707.956783  1009.0  2911.0
# MonthlyRate              1470.0  14313.103401  7117.786044  2094.0  8047.0
# NumCompaniesWorked       1470.0      2.693197     2.498009     0.0     1.0
# PercentSalaryHike        1470.0     15.209524     3.659938    11.0    12.0
# TotalWorkingYears        1470.0     11.279592     7.780782     0.0     6.0
# TrainingTimesLastYear    1470.0      2.799320     1.289271     0.0     2.0
# YearsAtCompany           1470.0      7.008163     6.126525     0.0     3.0
# ...

# %%
# Vẽ Boxplot từng biến số
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# # Nhận xét: Nhìn sơ qua thì số liệu khá ổn định, không có dữ liệu bất thường nào.

# %%
# Bỏ để đỡ gây nhiễu:
df.drop(columns=['MonthlyRate'], inplace=True)

# %% [markdown]
# - Trong quá trình khám phá dữ liệu (EDA), chúng tôi nhận thấy biến MonthlyRate có phân bố giá trị rất rộng, dao động từ 2.094 đến 26.999 USD.
# Tuy nhiên, khi so sánh với các biến kinh tế khác như MonthlyIncome – vốn trực tiếp thể hiện thu nhập thực tế của nhân viên, thì MonthlyRate không có mối quan hệ rõ ràng với việc nghỉ việc (Attrition).

# %%
# Chuẩn hóa datatype
for col in categorical_cols + [target_col]:
    df[col] = df[col].astype('category')

print("✅ Đã chuẩn hóa datatype cho các biến phân loại.")
# Out:
# ✅ Đã chuẩn hóa datatype cho các biến phân loại.

# %%
#Phân nhóm
# Nhóm tuổi
df['AgeBand'] = pd.cut(
    df['Age'], 
    bins=[17, 25, 30, 35, 40, 60], 
    labels=['18-25', '26-30', '31-35', '36-40', '41+']
)

df['AgeBand'] = df['AgeBand'].astype('category')

print("✅ Đã sinh biến AgeBand.")

# Nhóm thâm niên làm việc
df['TenureBand'] = pd.cut(
    df['YearsAtCompany'],
    bins=[-1, 1, 3, 5, 10, 40],
    labels=['<1y', '1-3y', '3-5y', '5-10y', '>10y']
)

df['TenureBand'] = df['TenureBand'].astype('category')

print("✅ Đã sinh biến TenureBand.")


# Nhóm mức thu nhập
df['IncomeBand'] = pd.cut(
    df['MonthlyIncome'],
    bins=[0, 3000, 5000, 8000, 12000, 20000],
    labels=['Low', 'Lower-Mid', 'Mid', 'Upper-Mid', 'High']
)

df['IncomeBand'] = df['IncomeBand'].astype('category')

print("✅ Đã sinh biến IncomeBand.")
# Out:
# ✅ Đã sinh biến AgeBand.
# ✅ Đã sinh biến TenureBand.
# ✅ Đã sinh biến IncomeBand.

# %% [markdown]
# # KPI 1: Tỷ lệ nghỉ việc (Attrition Rate) theo Phòng ban và Chức danh công việc (Department/JobRole)
# - Sau khi nhận diện được tỷ lệ nghỉ việc chung toàn công ty, câu hỏi tiếp theo chúng tôi đặt ra là: "Vậy thì, nhân viên ở đâu đang nghỉ việc nhiều nhất?"
#
# Không phải tất cả các phòng ban hay chức danh đều chịu ảnh hưởng như nhau. Một số bộ phận có thể đang ổn định, trong khi những bộ phận khác lại âm thầm mất đi một lượng lớn nhân viên.
#
# Việc phân tích tỷ lệ nghỉ việc theo từng Department (phòng ban) và Job Role (chức danh công việc) cho phép chúng ta:
#
# Khoanh vùng “ổ dịch” – những nơi có nguy cơ cao nhất.
#
# Ưu tiên nguồn lực – tập trung hành động ở những nơi cần thiết nhất.
#
# Hiểu sâu bản chất – xem liệu công việc, môi trường, hay yêu cầu công việc có đang ảnh hưởng đến quyết định rời đi của nhân viên hay không.
#
# Vì vậy, trong phần tiếp theo, chúng tôi sẽ phân tích Attrition Rate theo từng Department và Job Role nhằm xác định những điểm nóng về nghỉ việc trong tổ chức.

# %%
# Khám phá thông tin sơ bộ về phòng ban và role
# Tổng số nhân viên theo Department
dept_total = df['Department'].value_counts()

# Tổng số nhân viên theo JobRole
jobrole_total = df['JobRole'].value_counts()

# In ra kết quả
print("Tổng số nhân viên theo Department:")
print(dept_total)

print("\nTổng số nhân viên theo JobRole:")
print(jobrole_total)
# Out:
# Tổng số nhân viên theo Department:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
# Tổng số nhân viên theo JobRole:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
# Số nhân viên nghỉ việc theo Department
dept_left = df[df['Attrition'] == 'Yes']['Department'].value_counts()

# Số nhân viên nghỉ việc theo JobRole
jobrole_left = df[df['Attrition'] == 'Yes']['JobRole'].value_counts()

# In ra kết quả
print("Số nhân viên nghỉ việc theo Department:")
print(dept_left)

print("\nSố nhân viên nghỉ việc theo JobRole:")
print(jobrole_left)
# Out:
# Số nhân viên nghỉ việc theo Department:
# Department
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: count, dtype: int64
#
# Số nhân viên nghỉ việc theo JobRole:
# JobRole
# Laboratory Technician        62
# Sales Executive              57
# Research Scientist           47
# Sales Representative         33
# Human Resources              12
# Manufacturing Director       10
# Healthcare Representative     9
# Manager                       5
# Research Director             2
# Name: count, dtype: int64

# %%
# Tính tỷ lệ nghỉ việc theo Department
dept_attrition_rate = (dept_left / dept_total) * 100

# Tính tỷ lệ nghỉ việc theo JobRole
jobrole_attrition_rate = (jobrole_left / jobrole_total) * 100

# Sắp xếp giảm dần để tìm "ổ dịch"
dept_attrition_rate = dept_attrition_rate.sort_values(ascending=False)
jobrole_attrition_rate = jobrole_attrition_rate.sort_values(ascending=False)

# In ra
print("Attrition Rate theo Department (%):")
print(dept_attrition_rate)

print("\nAttrition Rate theo JobRole (%):")
print(jobrole_attrition_rate)
# Out:
# Attrition Rate theo Department (%):
# Department
# Sales                     20.627803
# Human Resources           19.047619
# Research & Development    13.839750
# Name: count, dtype: float64
#
# Attrition Rate theo JobRole (%):
# JobRole
# Sales Representative         39.759036
# Laboratory Technician        23.938224
# Human Resources              23.076923
# Sales Executive              17.484663
# Research Scientist           16.095890
# Manufacturing Director        6.896552
# Healthcare Representative     6.870229
# Manager                       4.901961
# Research Director             2.500000
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Vẽ biểu đồ Attrition Rate theo Department
plt.figure(figsize=(10,6))
sns.barplot(x=dept_attrition_rate.values, y=dept_attrition_rate.index, palette='viridis')
plt.title('Attrition Rate theo Department', fontsize=16)
plt.xlabel('Attrition Rate (%)', fontsize=14)
plt.ylabel('Department', fontsize=14)
plt.xlim(0, dept_attrition_rate.max() + 5)  # Để khoảng trống phải cho đẹp
plt.grid(axis='x')
plt.show()

# Vẽ biểu đồ Attrition Rate theo JobRole
plt.figure(figsize=(12,8))
sns.barplot(x=jobrole_attrition_rate.values, y=jobrole_attrition_rate.index, palette='magma')
plt.title('Attrition Rate theo Job Role', fontsize=16)
plt.xlabel('Attrition Rate (%)', fontsize=14)
plt.ylabel('Job Role', fontsize=14)
plt.xlim(0, jobrole_attrition_rate.max() + 5)
plt.grid(axis='x')
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_26228\2698961334.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dept_attrition_rate.values, y=dept_attrition_rate.index, palette='viridis')
# C:\Users\PC\AppData\Local\Temp\ipykernel_26228\2698961334.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=jobrole_attrition_rate.values, y=jobrole_attrition_rate.index, palette='magma')

# %% [markdown]
# - Nhận xét:
# 1. Theo Department:
# Bộ phận Sales ghi nhận tỷ lệ nghỉ việc cao nhất với mức 20.63%. Điều này cho thấy tính chất công việc tại Sales thường đi kèm với áp lực doanh số rất lớn và chỉ tiêu nặng nề. Sau biến động thị trường thời kỳ hậu Covid, sự cạnh tranh khốc liệt càng khiến nhân viên Sales dễ rơi vào trạng thái mệt mỏi và lựa chọn nhảy việc để tìm kiếm những cơ hội tốt hơn. Bên cạnh đó, cơ chế thưởng phạt tại Sales cũng thường không ổn định, đặc biệt khi doanh số không đạt kỳ vọng, càng làm gia tăng tỷ lệ rời bỏ.
#
# Human Resources cũng ghi nhận tỷ lệ nghỉ việc khá cao ở mức 19.05%. Bộ phận này hiện có thể đang gánh chịu áp lực kép: vừa phải đảm bảo công tác tuyển dụng trong bối cảnh thị trường nhân sự khan hiếm, vừa đối mặt với áp lực giữ chân nhân viên nội bộ trong lúc công ty đang trải qua những biến động.
#
# Đối với Research & Development, tỷ lệ nghỉ việc ở mức 13.84%, tương đối thấp hơn. Tuy nhiên, sự rời bỏ tại đây chủ yếu xuất phát từ nguyên nhân thiếu lộ trình phát triển nghề nghiệp rõ ràng cho nhóm kỹ thuật và nghiên cứu viên – những người vốn đề cao sự phát triển chuyên môn dài hạn.
#
# 2. Theo JobRole:
# Ở cấp độ chức danh, Sales Representative nổi bật lên với tỷ lệ nghỉ việc rất cao, đạt 39.76%. Đây là nhóm nhân sự tuyến đầu, thường xuyên phải đối mặt với áp lực doanh số khốc liệt và khối lượng công việc ngoài giờ (OT) đáng kể. Việc thiếu cơ hội thăng tiến nhanh chóng cùng với chế độ lương cố định thấp, phụ thuộc phần lớn vào thu nhập từ hoa hồng (commission), khiến họ dễ thất vọng khi kết quả kinh doanh không như kỳ vọng, từ đó gia tăng nguy cơ nghỉ việc.
#
# Đối với Laboratory Technician (23.94%) và Human Resources (23.08%), tỷ lệ nghỉ việc cũng ở mức cao. Nguyên nhân chủ yếu là do công việc thiên về tính lặp lại, ít đổi mới, trong khi cơ hội thăng tiến hoặc chuyển đổi nghề nghiệp lại khá hạn chế, khiến nhân sự cảm thấy bế tắc sau một vài năm làm việc.
#
# Ngược lại, các chức danh cấp quản lý như Manager và Research Director có tỷ lệ nghỉ việc thấp, chỉ dưới 5%. Điều này có thể lý giải bởi đặc quyền gắn liền với các vị trí quản lý cấp cao, đồng thời những nhân sự này thường đã có thời gian gắn bó lâu dài với tổ chức.

# %% [markdown]
# StoryTelling: Phân tích sâu tỷ lệ nghỉ việc theo từng bộ phận và chức danh cho thấy Sales nổi lên là "ổ dịch" chính, với tỷ lệ hơn 20%.
#
# Điều này không chỉ phản ánh áp lực doanh số mà còn gợi ý rằng chính sách phúc lợi và hỗ trợ trong Sales có thể chưa thực sự hiệu quả trong việc giữ chân nhân viên.
#
# Nghiêm trọng hơn, nhóm Sales Representative — tuyến đầu doanh thu — đang rời đi gần 4 trên 10 người, báo hiệu sự mất ổn định đáng báo động.
#
# Áp lực công việc, chế độ đãi ngộ chưa hấp dẫn và thiếu cơ hội phát triển lâu dài là những nguyên nhân nổi bật thúc đẩy làn sóng nghỉ việc này.
#
# Nếu không có hành động kịp thời, doanh thu công ty chắc chắn sẽ chịu tác động tiêu cực rõ rệt trong tương lai gần.
